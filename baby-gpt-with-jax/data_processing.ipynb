# %% [markdown]
# ## Data processing steps

# %% [markdown]
# #### Mount my drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Configuration

# %%
SOURCE_ROOT_PATH = "/content/drive/MyDrive/Ade-Colab-Notebooks/Large-Language-Models/gpt-jax-demo-another_one"
RAW_ZIP_DATA_PATH = f"{SOURCE_ROOT_PATH}/tinystories.zip"
LINES_PER_FILE = 200_000
RAW_DATA_PATH = f"{SOURCE_ROOT_PATH}/tiny_stories_{LINES_PER_FILE}.txt"

# %% [markdown]
# #### Imports

# %%
import sys
sys.path.append(SOURCE_ROOT_PATH)

from tiny_stories_dataset_provider import save_zipped_lines

# %%
save_zipped_lines(RAW_ZIP_DATA_PATH, RAW_DATA_PATH, LINES_PER_FILE, LINES_PER_FILE)
# Out:
# Writing lines: 397630 lines [00:01, 330767.85 lines/s]
# Succefully created /content/drive/MyDrive/Ade-Colab-Notebooks/Large-Language-Models/gpt-jax-demo-another_one/tiny_stories_200000.txt file with 200000 lines
